# %%
import warnings 
warnings.filterwarnings("ignore")
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.graph_objs as go
import plotly.express as px

# %%
heart_data=pd.read_csv("heart_failure_clinical_records_dataset.csv")

# %%
heart_data.head()
# Out:
#     age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0  75.0        0                       582         0                 20
# 1  55.0        0                      7861         0                 38
# 2  65.0        0                       146         0                 20
# 3  50.0        1                       111         0                 20
# 4  65.0        1                       160         1                 20
#
#    high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# 0                    1  265000.00               1.9           130    1
# 1                    0  263358.03               1.1           136    1
# 2                    0  162000.00               1.3           129    1
# 3                    0  210000.00               1.9           137    1
# 4                    0  327000.00               2.7           116    0
#
#    smoking  time  DEATH_EVENT
# 0        0     4            1
# 1        0     6            1
# ...

# %%
heart_data.describe()
# Out:
#               age     anaemia  creatinine_phosphokinase    diabetes  \
# count  299.000000  299.000000                299.000000  299.000000
# mean    60.833893    0.431438                581.839465    0.418060
# std     11.894809    0.496107                970.287881    0.494067
# min     40.000000    0.000000                 23.000000    0.000000
# 25%     51.000000    0.000000                116.500000    0.000000
# 50%     60.000000    0.000000                250.000000    0.000000
# 75%     70.000000    1.000000                582.000000    1.000000
# max     95.000000    1.000000               7861.000000    1.000000
#
#        ejection_fraction  high_blood_pressure      platelets  \
# count         299.000000           299.000000     299.000000
# mean           38.083612             0.351171  263358.029264
# std            11.834841             0.478136   97804.236869
# min            14.000000             0.000000   25100.000000
# ...

# %%
heart_data.isnull().sum()
# Out:
# age                         0
# anaemia                     0
# creatinine_phosphokinase    0
# diabetes                    0
# ejection_fraction           0
# high_blood_pressure         0
# platelets                   0
# serum_creatinine            0
# serum_sodium                0
# sex                         0
# smoking                     0
# time                        0
# DEATH_EVENT                 0
# dtype: int64

# %%
print("shape of the data set",heart_data.shape)
# Out:
# shape of the data set (299, 13)

# %%
heart_data.dtypes
# Out:
# age                         float64
# anaemia                       int64
# creatinine_phosphokinase      int64
# diabetes                      int64
# ejection_fraction             int64
# high_blood_pressure           int64
# platelets                   float64
# serum_creatinine            float64
# serum_sodium                  int64
# sex                           int64
# smoking                       int64
# time                          int64
# DEATH_EVENT                   int64
# dtype: object

# %% [markdown]
# # Data modeling

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score

# %%
#Feature=['time','ejection_fraction','serum_creatinine']
x=heart_data.drop(['DEATH_EVENT'],axis=1)
y=heart_data["DEATH_EVENT"]

# %%
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.2,random_state=2)

# %%
print("xtrain data")
print(xtrain)
print("xtest data")
print(xtest)
print("ytrain data")
print(ytrain)
print("ytest data")
print(ytest)
# Out:
# xtrain data
#       age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 53   70.0        1                        69         1                 50
# 172  70.0        1                       171         0                 60
# 23   53.0        0                        63         1                 60
# 98   60.0        1                       156         1                 25
# 244  54.0        0                       582         1                 38
# ..    ...      ...                       ...       ...                ...
# 75   60.0        1                        47         0                 20
# 22   68.0        1                       220         0                 35
# 72   85.0        0                      5882         0                 35
# 15   82.0        1                       379         0                 50
# 168  65.0        0                       582         1                 40
#
# ...

# %%
from sklearn.ensemble import RandomForestClassifier
import joblib

# %%
RF=RandomForestClassifier()
RF.fit(xtrain,ytrain)
RF_pred=RF.predict(xtest)
RF_accu=accuracy_score(ytest,RF_pred)
RF_preci=precision_score(ytest,RF_pred)
RF_recall=recall_score(ytest, RF_pred)
RF_con=confusion_matrix(ytest, RF_pred)
print("accuracy rate for RandomForestClassifier :", RF_accu*100)
print("precision_score for RandomForestClassifier :", RF_preci*100)
print("recall score for RandomForestClassifier:", RF_recall*100)
print("confusion_matrix for RandomForestClassifier:\n", RF_con)
# Out:
# accuracy rate for RandomForestClassifier : 95.0
# precision_score for RandomForestClassifier : 100.0
# recall score for RandomForestClassifier: 82.35294117647058
# confusion_matrix for RandomForestClassifier:
#  [[43  0]
#  [ 3 14]]
